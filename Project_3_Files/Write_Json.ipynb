# %%
import csv 
import json
import time
import pprint
from geojson import Point, Feature, FeatureCollection, dump

# %%
def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='utf-8') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 

        #convert each csv row into python dict
        for row in csvReader: 
            #add this python dict to json array
            jsonArray.append(row)
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)

# %%
          
csvFilePath = r'Project_3_Test_to_SQL.csv'
jsonFilePath = r'data.json'

start = time.perf_counter()
csv_to_json(csvFilePath, jsonFilePath)
finish = time.perf_counter()

# %%
from sys import argv
from os.path import exists 
import json 

script, in_file, out_file = argv

data = json.load(open("data.json"))

geojson = {
    "type": "FeatureCollection",
    "features": [
    {
        "type": "Feature",
        "geometry" : {
            "type": "Point",
            "coordinates": [d["LONGITUDE"], d["LATITUDE"]],
            },
        "properties" : d,
     } for d in data]
}


output = open(out_file, 'w')
json.dump(geojson, output)

print(geojson)

#  {
#         "index": "51884",
#         "EVENT_ID_CNTY": "UKR52150",
#         "EVENT_ID_NO_CNTY": "52150",
#         "EVENT_DATE": "2/24/2022",
#         "EVENT_TYPE": "Explosions",
#         "SUB_EVENT_TYPE": "Air Raid",
#         "ACTOR1": "Military Forces of Russia (2000-)",
#         "LOCATION": "Uman",
#         "LATITUDE": "48.748",
#         "LONGITUDE": "30.222",
#         "SOURCE": "24 Channel; Segodnya",
#         "NOTES": "On 24 February 2022, military forces of Russia launched a rocket attack on Uman, Cherkasy. As a result, one civilian was killed and five were wounded. The town began evacuation of its residents.",
#         "FATALITIES": "1"
#     },
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': ['30.222', '48.748']}, 'properties': {'index': '51884', 'EVENT_ID_CNTY': 'UKR52150', 'EVENT_ID_NO_CNTY': '52150', 'EVENT_DATE': '2/24/2022', 'EVENT_TYPE': 'Explosions', 'SUB_EVENT_TYPE': 'Air Raid', 'ACTOR1': 'Military Forces of Russia (2000-)', 'LOCATION': 'Uman', 'LATITUDE': '48.748', 'LONGITUDE': '30.222', 'SOURCE': '24 Channel; Segodnya', 'NOTES': 'On 24 February 2022, military forces of Russia launched a rocket attack on Uman, Cherkasy. As a result, one civilian was killed and five were wounded. The town began evacuation of its residents.', 'FATALITIES': '1'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': ['24.71', '48.922']}, 'properties': {'index': '51885', 'EVENT_ID_CNTY': 'UKR52162', 'EVENT_ID_NO_CNTY': '52162', 'EVENT_DATE': '2/24/2022', 'EVENT_TYPE': 'Explosions', 'SUB_EVENT_TYPE': 'Air Raid', 'ACTOR1': 'Military Forces of Russia (2000-)', 'LOCATI
# ...

# %%
print(json.dumps(geojson, indent=2))
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           "30.222",
#           "48.748"
#         ]
#       },
#       "properties": {
#         "index": "51884",
#         "EVENT_ID_CNTY": "UKR52150",
#         "EVENT_ID_NO_CNTY": "52150",
#         "EVENT_DATE": "2/24/2022",
#         "EVENT_TYPE": "Explosions",
#         "SUB_EVENT_TYPE": "Air Raid",
#         "ACTOR1": "Military Forces of Russia (2000-)",
#         "LOCATION": "Uman",
#         "LATITUDE": "48.748",
#         "LONGITUDE": "30.222",
#         "SOURCE": "24 Channel; Segodnya",
#         "NOTES": "On 24 February 2022, military forces of Russia launched a rocket attack on Uman, Cherkasy. As a result, one civilian was killed and five were wounded. The town began evacuation of its residents.",
#         "FATALITIES": "1"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
# ...

# %%
#feature_collection = FeatureCollection(features)

with open('geojson.json', 'w') as f:
   json.dump(geojson, f, indent=2)
